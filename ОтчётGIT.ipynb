# %% [markdown]
# # Титульный лист
# <a name = 'Титульный_лист'>

# %% [markdown]
# <font face="times new roman" size="3" color="black">
# <center> МИНИСТЕРСТВО ЦИФРОВОГО РАЗВИТИЯ, СВЯЗИ И МАССОВЫХ КОММУНИКАЦИЙ РОССИЙСКОЙ ФЕДЕРАЦИИ </center>
# <center>Ордена Трудового Красного Знамени федеральное государственное бюджетное образовательное учреждение высшего образования </center>
# <center> <strong> «Московский технический университет связи и информатики» </strong> </center>
#
#   <hr>
# <center> Кафедра «Телевидения и звукового вещания им. С.И. Катаева (ТиЗВ)» </center>
# <br>
# <center> <font face="times new roman" size="3" color="black"> Отчет по лабораторной работе № 12</center>
# <center>по дисциплине </center>
# <center><b>«Информационные технологии и программирование»</b></center>
# <center>на тему</center>
# <center><b>«Системы контроля версий»</b> </center>
#
# </font>
#
#   <br><br><br><br><br>
#   <p  align="right"> <font face="times new roman" size="3" color="black"> Выполнил: студент группы </p>
#   <p  align="right"> <font face="times new roman" size="3" color="black">       БИК-2305 </p>
#   <p  align="right"> <font face="times new roman" size="3" color="black"> Дождиков Роман Алексеевич</p>
#   <p  align="right"> <font face="times new roman" size="3" color="black"> Проверил:</p>
#   <p  align="right"> <font face="times new roman" size="3" color="black"> Ассистент кафедры ТиЗВ Кудряшов Всеволод Владимирович </p>
#   <br>
#   <br>
#
#   <p  align="center"> <font face="times new roman" size="2" color="black"> Москва, 2023 г. </p>
#   <hr>

# %% [markdown]
# #Содержание

# %% [markdown]
# [1. Титульный лист](#Титульный_лист)
#
# <a href = '#Постановка_задач'>2. Постановка задач </a>
#
# <a href = '#Ход_работы'>3. Ход работы </a>
#
# <a href = '#Результат_выполнения_работы'> 4. Результат выполнения работы </a>

# %% [markdown]
# # Постановка задач
# <a name = 'Постановка_задач'>

# %% [markdown]
# ##Задание

# %% [markdown]
# 1. Установить GIT.
#
# 2. Создать локальный репозиторий.
#
# 3. Создать файл отчета по выполнению практической работы и поместить его в репозиторий
#
# 4. Зафиксируйте в отчете все проделанные шаги и создайте версию отчета в GIT
#
# 5. Создайте ветку отчета в GIT, добавьте описания шагов в отчет и создайте версию отчета в новой ветке.
#
# 6. Слейте последнее изменение отчета в основную ветку.
# Регистрируемся на github (или используем уже существующий аккаунт), создаем проект «homework IIT», залейте содержимое из локального репозитория в проект на githab.
#
# 7. Разместить на github ранее созданный статический сайт.
#
# 8. Завершить отчет, добавив описание всех пунктов.

# %% [markdown]
# ##Цель работы

# %% [markdown]
# Git репозиторий работающий и локально и на GitHub

# %% [markdown]
# ##Задачи на практическую работу

# %% [markdown]
# 1.   Установить GIT.
# (Материал для изучения – https://gitforwindows.org/ )
# 2.   Создать локальный репозиторий.
# (Материал для изучения – https://habr.com/ru/post/273897/ )
# 3.   Создать файл отчета по выполнению практической работы и поместить его в репозиторий
# 4.   Зафиксируйте в отчете все проделанные шаги и создайте версию отчета в GIT
# 5.   Создайте ветку отчета в GIT, добавьте описания шагов в отчет и создайте версию отчета в новой ветке.
# (Материал для изучения – https://habr.com/ru/post/342116/ )
# 6.   Слейте последнее изменение отчета в основную ветку.
# 7.   Регистрируемся на github (или используем уже существующий аккаунт), создаем проект «homework IIT», залете содержимое из локального репозитория в проект на githab.
# (Материал для изучения – https://smartiqa.ru/courses/git/lesson-6 )
# 8.   Слейте последнее изменение отчета в основную ветку.
# 9.   Разместить на github ранее созданный статический сайт.
# (Материал для изучения – https://htmlacademy.ru/blog/git/github-as-hosting )

# %% [markdown]
# ## Расчет входных данных

# %% [markdown]
# Установил GIT с официального сайта

# %% [markdown]
# # Ход работы
# <a name = "Ход_работы">

# %% [markdown]
# ###Решение 1 задачи

# %% [markdown]
# Установил GIT с официального сайта

# %% [markdown]
# ![Screenshot_1.png](data:image/png;base64,...)

# %% [markdown]
# ###Решение 2 задачи

# %% [markdown]
# Создал локальный репозиторий

# %% [markdown]
# ![Screenshot_2.png](data:image/png;base64,...)

# %% [markdown]
# ###Решение 3 задачи

# %% [markdown]
# Поместил файл отчёта в локальный репозиторий

# %% [markdown]
# ![Screenshot_3.png](data:image/png;base64,...)

# %% [markdown]
# ##Решение 4 задачи

# %% [markdown]
# Содержание отчёта

# %% [markdown]
# ![Screenshot_4.png](data:image/png;base64,...)

# %% [markdown]
# Зафиксировал проделанные шаги командой commit, перед этим меня конечно же спросили: "А кто ты такой?"

# %% [markdown]
# ![Screenshot_5.png](data:image/png;base64,...)

# %% [markdown]
# ##Решение 5 задачи

# %% [markdown]
# Создао новую ветку GIT, а также сохранил в ней новую версию отчёта (перед этим затупил, не заменив старую версию отчёта на новую).![Screenshot_6.png](data:image/png;base64,...![Screenshot_7.png](data:image/png;base64,...))

# %% [markdown]
# ##Решение 6 задачи

# %% [markdown]
# Слияние веток master и creating_report

# %% [markdown]
# ![Screenshot_7.png](data:image/png;base64,...)

# %% [markdown]
# ##Решение 7 задачи

# %% [markdown]
# Создал аккаунт на GitHub, установил GitHub Dekstop и с помощью него загрузил локальную репозиторию в GitHub.![Screenshot_8.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot_9.png](data:image/png;base64,...)

# %% [markdown]
# ##Решение 8 задачи

# %% [markdown]
# Размещение последней версии на GitHub

# %% [markdown]
# ##Решение 9 задачи

# %% [markdown]
# #Результат выполнения работы
# <a name = 'Результат_выполнения_работы'>
